# %% [markdown]
# # 1

# %%
from helper import aoc
year=2017
day=1
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )

# %% [markdown]
# # 2

# %%
from helper import aoc
year=2017
day=2
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )

# %% [markdown]
# # 3

# %%
from helper import aoc
year=2017
day=3
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )

# %% [markdown]
# # 4

# %%
from helper import aoc
year=2017
day=4
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )

# %% [markdown]
# # 5

# %%
from helper import aoc
year=2017
day=5
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )

# %% [markdown]
# # 6

# %%
from helper import aoc
year=2017
day=6
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )

# %% [markdown]
# # 7

# %%
from helper import aoc
year=2017
day=7
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )

# %% [markdown]
# # 8

# %%
from helper import aoc
year=2017
day=8
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )

# %% [markdown]
# # 9

# %%
from helper import aoc
year=2017
day=9
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )

# %% [markdown]
# # 10

# %%
from helper import aoc
year=2017
day=10
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )

# %% [markdown]
# # 11

# %%
from helper import aoc
year=2017
day=11
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )

# %% [markdown]
# # 12

# %%
from helper import aoc
year=2017
day=12
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )

# %% [markdown]
# # 13

# %%
from helper import aoc
year=2017
day=13
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )

# %% [markdown]
# # 14

# %%
from helper import aoc
year=2017
day=14
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )

# %% [markdown]
# # 15

# %%
from helper import aoc
year=2017
day=15
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )

# %% [markdown]
# # 16

# %%
from helper import aoc
year=2017
day=16
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )

# %% [markdown]
# # 17

# %%
from helper import aoc
year=2017
day=17
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )

# %% [markdown]
# # 18

# %%
from helper import aoc
year=2017
day=18
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )

# %% [markdown]
# # 19

# %%
from helper import aoc
year=2017
day=19
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )

# %% [markdown]
# # 20

# %%
from helper import aoc
year=2017
day=20
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )

# %% [markdown]
# # 21

# %%
from helper import aoc
year=2017
day=21
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )

# %% [markdown]
# # 22

# %%
from helper import aoc
year=2017
day=22
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )

# %% [markdown]
# # 23

# %%
from helper import aoc
year=2017
day=23
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )

# %% [markdown]
# # 24

# %%
from helper import aoc
year=2017
day=24
fileName=aoc.init(day,year)

f = open( fileName  , 'r' )
